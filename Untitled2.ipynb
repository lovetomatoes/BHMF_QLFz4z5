# %%
from PYmodule import *
from PYmodule.l_intg import *
import matplotlib.ticker as ticker
# plt.style.use('classic')
# %matplotlib inline

# %%
fig, ax = plt.subplots(figsize=(10,8))
ax.plot(np.arange(10),np.arange(10))
secax = ax.secondary_yaxis(1.0)
# secax.set_yticks([1e2,1e4,1e6,1e8,1e10])
# secax.yaxis.set_major_locator(ticker.NullLocator())
# secax.xaxis.set_minor_locator(ticker.NullLocator())
secax.tick_params(direction='in')
# secax.yaxis.set_minor_formatter(matplotlib.ticker.NullFormatter())

# ax.tick_params( bottom=False, top=False, left=True, right=False)
secax.tick_params( labelbottom=True, labeltop=False, labelleft=True, labelright=False)
# secax.get_yaxis().set_visible(False)
secax.get_yaxis().set_ticks([])
labels = [item.get_text() for item in secax.get_yticklabels()]

empty_string_labels = ['']*len(labels)
secax.set_yticklabels(empty_string_labels)

# plt.axis('off')
# ax.tick_params(axis='both', left=True, top=False, right=True, bottom=False, labelleft=True, labeltop=False, labelright=False, labelbottom=False)

fig.savefig("aa.png")
