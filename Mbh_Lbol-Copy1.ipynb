# %%
from PYmodule import *
from matplotlib.legend_handler import HandlerLine2D, HandlerTuple
import matplotlib.ticker as ticker
from scipy.ndimage.filters import gaussian_filter

# %matplotlib inline

# %% [raw]
# prex = '../temp/distf2N5_08211127_'
# T_M = np.loadtxt(prex+'Mevol.txt') # each line a BH growth track; all end with M>1e8
# T_l = np.loadtxt(prex+'levol.txt') # each line a BH growth track; all end with M>1e8
# T_t = np.loadtxt(prex+'tevol.txt') # each line a lambda track; all end with M>1e8
# T_z = np.loadtxt(prex+'zevol.txt') # each line a lambda track; all end with M>1e8
# print(len(T_M))
#
# M1 = T_M.transpose()[-1]
# L1 = L_M(T_l.transpose()[-1], M1)
# M1 = M1[L1>1e46]
# L1 = L1[L1>1e46]

# %%
# 
T_ = ascii.read('../temp/distf2N4_08211421_BHatz6.txt',guess=False, delimiter=' ')
T_ = ascii.read('../temp/distf2N6_08212227_BHatz6.txt',guess=False, delimiter=' ')

M1, L1, ls = T_['M1'], T_['L1'], T_['ls']

# %%
# M1 = M1[L1>1e46]
# M1= M1[L1>1e46];  ls= ls[L1>1e46]; L1= L1[L1>1e46];
# np.min(M1), np.min(L1)

# %% [raw]
# ZA = plt.hist2d(np.log10(fitting['bayes.stellar.m_star']),np.log10(fitting['bayes.sfh.sfr']), bins=(40,34), alpha=1,cmap='Greys_r')
# data = np.transpose(ZA[0])
# dt = gaussian_filter(data, 0.9)
# plt.contour(ZA[1][1:]-0.04,ZA[2][1:]-0.097,dt,cmap='plasma',alpha=0.9,linewidth=5)  # star forming

# %%
int(np.min(np.log10(M1)))
# Out:
# 3

# %%
xgrid = np.linspace(6, 10)
ygrid = np.linspace(44, 48)
X, Y = np.meshgrid((xgrid[:-1]+xgrid[1:])/2., (ygrid[:-1]+ygrid[1:])/2.)
Z = np.sqrt(X**2 + Y**2)
Z = plt.hist2d(np.log10(M1), np.log10(L1), [xgrid,ygrid])[0]

plt.plot(xgrid,np.log10(L_M(pow(10.,xgrid),.01)),'-.',c='k')
plt.plot(xgrid,np.log10(L_M(pow(10.,xgrid),.1)),'--',c='k')
plt.plot(xgrid,np.log10(L_M(pow(10.,xgrid),1)),'-',c='k')
plt.plot(xgrid,np.log10(L_M(pow(10.,xgrid),10)),'-',c='k')

# %%
xgrid = np.linspace( 3, 10, 15)
ygrid = np.linspace(41, 47, 15)
ZA = plt.hist2d(np.log10(M1),np.log10(L1), bins=(20,20), density=False, alpha=1,cmap='Greys_r')
# ZA = plt.hist2d(np.log10(M1),np.log10(L1), bins=(xgrid,ygrid), density=True, alpha=1,cmap='Greys_r')

data = np.transpose(ZA[0])
dt = gaussian_filter(data, .9)
ZA
# Out:
# (array([[2.20000e+01, 3.70000e+01, 3.70000e+01, 3.20000e+01, 2.20000e+01,
#          6.00000e+00, 1.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#          0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#          0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00],
#         [6.00000e+01, 7.05000e+02, 8.67000e+02, 9.61000e+02, 9.14000e+02,
#          4.96000e+02, 1.11000e+02, 3.00000e+00, 0.00000e+00, 0.00000e+00,
#          0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#          0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00],
#         [0.00000e+00, 1.59800e+03, 6.17500e+03, 7.25200e+03, 7.77900e+03,
#          6.68200e+03, 3.25800e+03, 4.49000e+02, 4.00000e+00, 0.00000e+00,
#          0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#          0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00],
#         [0.00000e+00, 0.00000e+00, 1.25380e+04, 2.69850e+04, 3.11950e+04,
# ...

# %%
ZA[1][2:]
# Out:
# array([ 4.26546716,  4.6195073 ,  4.97354743,  5.32758757,  5.68162771,
#         6.03566785,  6.38970799,  6.74374812,  7.09778826,  7.4518284 ,
#         7.80586854,  8.15990867,  8.51394881,  8.86798895,  9.22202909,
#         9.57606923,  9.93010936, 10.2841495 , 10.63818964])

# %%
T_BHs = ascii.read(datapre+'MgII_literatures_z6.csv',guess=False, delimiter=',')
# MBH_VO09 Lbol;Lbol_Ledd_VO09
T_BHs.info

plt.scatter(T_BHs['MBH_VO09'], T_BHs['Lbol'])
# plt.xscale('log'); plt.yscale('log')

# %%
len(T_),
SampleNames=['WIllott10','Shen19','HSC']
markers = ['s','D','o']

# %%
ZA[1][1:]/len(T_),ZA[2][1:]/len(T_)
# Out:
# (array([7.82285404e-07, 8.53093432e-07, 9.23901459e-07, 9.94709487e-07,
#         1.06551751e-06, 1.13632554e-06, 1.20713357e-06, 1.27794160e-06,
#         1.34874962e-06, 1.41955765e-06, 1.49036568e-06, 1.56117371e-06,
#         1.63198173e-06, 1.70278976e-06, 1.77359779e-06, 1.84440582e-06,
#         1.91521385e-06, 1.98602187e-06, 2.05682990e-06, 2.12763793e-06]),
#  array([8.05469167e-06, 8.14332977e-06, 8.23196788e-06, 8.32060599e-06,
#         8.40924409e-06, 8.49788220e-06, 8.58652031e-06, 8.67515841e-06,
#         8.76379652e-06, 8.85243463e-06, 8.94107273e-06, 9.02971084e-06,
#         9.11834895e-06, 9.20698705e-06, 9.29562516e-06, 9.38426327e-06,
#         9.47290137e-06, 9.56153948e-06, 9.65017759e-06, 9.73881569e-06]))

# %%
levels=np.logspace(-4,-.5,num=5)
levels
# Out:
# array([1.00000000e-04, 7.49894209e-04, 5.62341325e-03, 4.21696503e-02,
#        3.16227766e-01])

# %%
np.sum(ZA[1][1:])+np.sum(ZA[2][1:])
# Out:
# 1035.1715345622865

# %%
fig,ax = plt.subplots(1,1)#,figsize=(10,8)
M = np.logspace(4,10)
ax.plot(np.log10(M),np.log10(L_M(M,1)),c='k')
ax.plot(np.log10(M),np.log10(L_M(M,10)),c='k')
ax.plot(np.log10(M),np.log10(L_M(M,.1)),'--',c='k')
ax.plot(np.log10(M),np.log10(L_M(M,.01)),'-.',c='k')
# levels=[1e-4,3e-4,1e-3,3e-3,1e-2,1e-1,3e-1]
# levels=np.logspace(-4,-.5,num=10)
# /len(T_)

# cp=ax.contour(ZA[1][1:],ZA[2][1:],dt,colors='k',levels=np.logspace(-4,-.5,num=5),alpha=1,linewidths=1)  # star forming
# plt.clabel(cp, inline=True, fontsize=12)

cp=ax.contourf(ZA[1][1:],ZA[2][1:],dt,cmap="Blues_r",norm=matplotlib.colors.LogNorm(),levels=np.logspace(-4,-.5,num=5),alpha=.5,linewidths=1)  # star forming
fig.colorbar(cp) # Add a colorbar to a plot

# cp=ax.contourf(ZA[1][1:],ZA[2][1:],dt,
# #                levels=np.logspace(-4,-.5,num=8),
# #                levels=np.array([.001,.01,0.1,0.5,0.9]),
#                levels=14,
#                locator=ticker.LogLocator(), cmap=cm.PuBu_r)
#                extend='both', \
#                colors=('#ff0000', '#ff9900', '#999900', 'w', '#009999', '#0099ff', '#0000ff'))
              # colors=('w', '#ff9900', '#999900'))#, 'w', '#009999', '#0099ff', '#ff0000'))
ax.set_xlim(5,10)
ax.set_xlim(3,11)
ax.set_ylim(44,48)
ax.set_ylim(40,48)
ax.set_yticks(np.arange(44,49))

for i in range(3):
    Name = SampleNames[i]
    index = np.where(T_BHs['reference'] == Name)
    plt.scatter(np.log10(T_BHs['MBH_VO09'][index]), np.log10(T_BHs['Lbol'][index]), marker=markers[i],facecolor='None',edgecolor='C'+str(i))
    if Name=='WIllott10':
        print(T_BHs['Lbol_Ledd_VO09'][index])


ax.set_xlabel(r'$\mathrm{M_{1450}}$',fontsize=fslabel)
ax.set_ylabel(r'$\mathrm{\Phi_{M_{1450}}~(Mpc^{-3}mag^{-1})}$',fontsize=fslabel)

fig.savefig(figpre+'ML.pdf',dpi=300,bbox_inches='tight')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: Log scale: values of z <= 0 have been masked
#
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: linewidths is ignored by contourf
# Lbol_Ledd_VO09
# --------------
#          0.544
#          1.068
#          2.146
#          0.292
#          0.601
#          2.027
#          0.426
#          2.092
#          1.156

# %%
fig,ax = plt.subplots(1,1)
M = np.logspace(4,10)
# ax.plot(np.log10(M),np.log10(L_M(M,10)),c='k')
ax.plot(np.log10(M),np.log10(L_M(M,1)),c='k',lw=1,alpha=.5)
ax.plot(np.log10(M),np.log10(L_M(M,.1)),'--',c='k',lw=1,alpha=.5)
ax.plot(np.log10(M),np.log10(L_M(M,.01)),'-.',c='k',lw=1,alpha=.5)
# levels=[1e-4,3e-4,1e-3,3e-3,1e-2,1e-1,3e-1]
# levels=np.logspace(-4,-.5,num=10)
# /len(T_)

# cp=ax.contour(ZA[1][1:],ZA[2][1:],dt,colors='k',levels=np.logspace(-4,-.5,num=5),alpha=1,linewidths=1)  # star forming
# plt.clabel(cp, inline=True, fontsize=12)

cp=ax.contourf(ZA[1][1:],ZA[2][1:],dt,cmap="Blues_r",norm=matplotlib.colors.LogNorm(),levels=np.logspace(-4,-.5,num=5),alpha=.7,linewidths=1,zorder=0)  # star forming
fig.colorbar(cp) # Add a colorbar to a plot

# cp=ax.contourf(ZA[1][1:],ZA[2][1:],dt,
# #                levels=np.logspace(-4,-.5,num=8),
# #                levels=np.array([.001,.01,0.1,0.5,0.9]),
#                levels=14,
#                locator=ticker.LogLocator(), cmap=cm.PuBu_r)
#                extend='both', \
#                colors=('#ff0000', '#ff9900', '#999900', 'w', '#009999', '#0099ff', '#0000ff'))
              # colors=('w', '#ff9900', '#999900'))#, 'w', '#009999', '#0099ff', '#ff0000'))
ax.set_xlim(5,10)
ax.set_xlim(3,11)
ax.set_ylim(44,48)
ax.set_ylim(40,48)
ax.set_yticks(np.arange(44,49))

for i in range(3):
    Name = SampleNames[i]
    index = np.where(T_BHs['reference'] == Name)
    plt.scatter(np.log10(T_BHs['MBH_VO09'][index]), np.log10(T_BHs['Lbol'][index]), marker=markers[i],facecolor='None',alpha=.7,edgecolor='C'+str(i+1))
    if Name=='WIllott10':
        print(T_BHs['Lbol_Ledd_VO09'][index])


ax.set_xlabel(r'$\mathrm{M_{\bullet}~(M_\odot)}$',fontsize=15)
ax.set_ylabel(r'$\mathrm{L_{bol}~(erg~s^{-1})}$',fontsize=15)

fig.savefig(figpre+'ML.pdf',dpi=300,bbox_inches='tight')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: Log scale: values of z <= 0 have been masked
#
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: linewidths is ignored by contourf
# Lbol_Ledd_VO09
# --------------
#          0.544
#          1.068
#          2.146
#          0.292
#          0.601
#          2.027
#          0.426
#          2.092
#          1.156

# %%
fig,ax = plt.subplots(1,1)
M = np.logspace(4,10)
ax.plot(np.log10(M),np.log10(L_M(M,1)),c='k')
ax.plot(np.log10(M),np.log10(L_M(M,10)),c='k')
ax.plot(np.log10(M),np.log10(L_M(M,.1)),'--',c='k')
ax.plot(np.log10(M),np.log10(L_M(M,.01)),'-.',c='k')
# levels=[1e-4,3e-4,1e-3,3e-3,1e-2,1e-1,3e-1]
# levels=np.logspace(-4,-.5,num=10)
# /len(T_)
cp=ax.contour(pow(10.,ZA[1][1:]),pow(10.,ZA[2][1:]),dt,colors='k',levels=np.logspace(-3.5,-.5,num=5),alpha=1,linewidths=1)  # star forming
# cp=ax.contourf(ZA[1][1:],ZA[2][1:],dt,cmap='Oranges',levels=np.logspace(-4,-.5,num=5),alpha=1,linewidths=1)  # star forming
# fig.colorbar(cp) # Add a colorbar to a plot

ax.set_xlim(1e5,1e10)
ax.set_ylim(1e44,1e48)
ax.set_xscale('log')
ax.set_yscale('log')
# ax.set_yticks(np.arange(44,49))
ax.set_xlabel(r'$\mathrm{M_{\bullet}~(M_\odot)}$',fontsize=fslabel)
ax.set_ylabel(r'$\mathrm{L_{bol}~(erg~s^{-1})}$',fontsize=fslabel)

for i in range(3):
    Name = SampleNames[i]
    index = np.where(T_BHs['reference'] == Name)
    plt.scatter(T_BHs['MBH_VO09'][index], T_BHs['Lbol'][index], marker=markers[i],facecolor='None',alpha=.7,edgecolor='C'+str(i+1))
    if Name=='WIllott10':
        print(T_BHs['Lbol_Ledd_VO09'][index])



fig.savefig(figpre+'ML.pdf',dpi=300,bbox_inches='tight')
# Out:
# Lbol_Ledd_VO09
# --------------
#          0.544
#          1.068
#          2.146
#          0.292
#          0.601
#          2.027
#          0.426
#          2.092
#          1.156

# %%
fig,ax = plt.subplots(1,1)
M = np.logspace(4,10)
ax.plot(np.log10(M),np.log10(L_M(M,1)),c='C0')
ax.plot(np.log10(M),np.log10(L_M(M,.1)),c='C1')
ax.plot(np.log10(M),np.log10(L_M(M,.01)),c='C2')

cp=ax.contourf(ZA[1][1:],ZA[2][1:],dt,cmap='Oranges',levels=[1e-4,3e-4,1e-3,3e-3,1e-2,1e-1,3e-1],alpha=1,linewidths=1)  # star forming
ax.set_xlim(5,10)
ax.set_ylim(bottom=40)
fig.colorbar(cp) # Add a colorbar to a plot
fig.savefig(figpre+'ML.pdf',dpi=300,bbox_inches='tight')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: linewidths is ignored by contourf
#   import sys

# %%
from matplotlib import ticker, cm

plt.contourf(ZA[1][1:],ZA[2][1:],dt,cmap=cm.PuBu_r,alpha=1,linewidth=3)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.contour(ZA[1][1:],ZA[2][1:],dt,cmap=cm.cividis,alpha=1,linewidth=3, bins=20)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: The following kwargs were not used by contour: 'linewidth', 'bins'
#   """Entry point for launching an IPython kernel.

# %%
xgrid = np.linspace(6, 10)
ygrid = np.linspace(44, 48)
X, Y = np.meshgrid((xgrid[:-1]+xgrid[1:])/2., (ygrid[:-1]+ygrid[1:])/2.)
Z = np.sqrt(X**2 + Y**2)
Z = plt.hist2d(np.log10(M1), np.log10(L1), [xgrid,ygrid])[0]


fig,ax=plt.subplots(1,1)
cp = ax.contourf(X, Y, Z)
fig.colorbar(cp) # Add a colorbar to a plot
# ax.set_title('Filled Contours Plot')
#ax.set_xlabel('x (cm)')
ax.set_ylabel('y (cm)')
plt.show()

# %%
np.max(np.log10(L1))
# Out:
# 48.69407846208076
